# %% [markdown]
# устанавливаем и импортируем нужные библиотеки

# %%
pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydicom
#   Downloading pydicom-2.3.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 14.0 MB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-2.3.0

# %%
pip install pyradiomics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyradiomics
#   Downloading pyradiomics-3.0.1-cp37-cp37m-manylinux1_x86_64.whl (188 kB)
#      |████████████████████████████████| 188 kB 8.4 MB/s
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from pyradiomics) (1.3.0)
# Collecting SimpleITK>=0.9.1
#   Downloading SimpleITK-2.1.1.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (48.4 MB)
#      |████████████████████████████████| 48.4 MB 31 kB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from pyradiomics) (1.15.0)
# Collecting pykwalify>=1.6.0
#   Downloading pykwalify-1.8.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.7/dist-packages (from pyradiomics) (1.21.6)
# Collecting ruamel.yaml>=0.16.0
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 45.9 MB/s
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from pykwalify>=1.6.0->pyradiomics) (2.8.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from pykwalify>=1.6.0->pyradiomics) (0.6.2)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.6-cp37-cp37m-manylinux1_x86_64.whl (546 kB)
#      |████████████████████████████████| 546 kB 47.2 MB/s
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml, SimpleITK, pykwalify, pyradiomics
# Successfully installed SimpleITK-2.1.1.2 pykwalify-1.8.0 pyradiomics-3.0.1 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.6

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import SimpleITK as sitk

# %%
import os

# %%
import pydicom

# %%
import radiomics

# %%
from pydicom import dcmread

# %% [markdown]
# откроем и выведем картинки снимка и маски

# %%
# via dcmread from pydicom

ds = dcmread('/content/drive/MyDrive/practice/data/nativ/IMG-0001-00049.dcm')

# %%
plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
plt.show()

# %%
ds_mask = dcmread('/content/drive/MyDrive/practice/data/liver thing label/IMG0049.dcm')

# %%
plt.imshow(ds_mask.pixel_array, cmap=plt.cm.gray)
plt.show()

# %%
# теперь другой вариант, сохранили серии в формате nii.gz, чтобы можно было выбирать слой

image = sitk.ReadImage('/content/drive/MyDrive/practice/data/3 NATIV 1.25 SFT.nii.gz')
segmentation = sitk.ReadImage('/content/drive/MyDrive/practice/data/1 No series description.nii.gz')

# %%
# number of slice for plotting
z = 180

# window settings
hu_l = -100
hu_h = 200

array_img = sitk.GetArrayFromImage(image)
array_seg = sitk.GetArrayFromImage(segmentation)

I = np.fliplr(np.flipud(array_img[z, :, :]))
S = np.fliplr(np.flipud(array_seg[z, :, :]))

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(I, cmap='gray', vmin=hu_l, vmax=hu_h)
plt.subplot(1, 2, 2)
plt.imshow(S, cmap='gray')
plt.show()

# %%
from radiomics import featureextractor

# %%
extractor = featureextractor.RadiomicsFeatureExtractor('/content/drive/MyDrive/practice/data/exampleCT_config.yaml', preCrop=True)
# Out:
# INFO:radiomics.featureextractor:Loading parameter file /content/drive/MyDrive/practice/data/exampleCT_config.yaml
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'preCrop': True}

# %%
extractor.disableAllFeatures()
extractor.disableAllImageTypes()
extractor.enableImageTypeByName('Original')
extractor.enableFeaturesByName(firstorder=['Mean', 'Median', 'StandardDeviation'], shape=['Maximum2DDiameterSlice', 'Maximum2DDiameterColumn', 'Maximum2DDiameterRow', 'MajorAxisLength', 'MinorAxisLength', 'VoxelVolume'])

# %%
extractor.settings
# Out:
# {'additionalInfo': True,
#  'binWidth': 16,
#  'distances': [1],
#  'force2D': False,
#  'force2Ddimension': 0,
#  'interpolator': 'sitkLinear',
#  'label': 1,
#  'minimumROIDimensions': 2,
#  'minimumROISize': None,
#  'normalize': False,
#  'normalizeScale': 1,
#  'padDistance': 5,
#  'preCrop': True,
#  'removeOutliers': None,
#  'resampledPixelSpacing': [1, 1, 1],
#  'resegmentRange': None,
#  'voxelArrayShift': 1050}

# %%
result = extractor.execute(image, segmentation, label=1)
# Out:
# INFO:radiomics.featureextractor:Calculating features with label: 1
# INFO:radiomics.featureextractor:Loading image and mask
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.97070301 0.97070301 1.        ] and size [512 512 231] to spacing [1. 1. 1.] and size [43, 38, 35]
# INFO:radiomics.featureextractor:Computing shape
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# INFO:radiomics.featureextractor:Calculating features for original image
# INFO:radiomics.featureextractor:Computing firstorder
# Feature StandardDeviation is deprecated, use with caution!
# WARNING:radiomics.firstorder:Feature StandardDeviation is deprecated, use with caution!

# %%
result
# Out:
# OrderedDict([('diagnostics_Versions_PyRadiomics', 'v3.0.1'),
#              ('diagnostics_Versions_Numpy', '1.21.6'),
#              ('diagnostics_Versions_SimpleITK', '2.1.1.2'),
#              ('diagnostics_Versions_PyWavelet', '1.3.0'),
#              ('diagnostics_Versions_Python', '3.7.13'),
#              ('diagnostics_Configuration_Settings',
#               {'additionalInfo': True,
#                'binWidth': 16,
#                'distances': [1],
#                'force2D': False,
#                'force2Ddimension': 0,
#                'interpolator': 'sitkLinear',
#                'label': 1,
#                'minimumROIDimensions': 2,
#                'minimumROISize': None,
#                'normalize': False,
#                'normalizeScale': 1,
#                'padDistance': 5,
#                'preCrop': True,
#                'removeOutliers': None,
#                'resampledPixelSpacing': [1, 1, 1],
#                'resegmentRange': None,
#                'voxelArrayShift': 1050}),
#              ('diagnostics_Configuration_EnabledImageTypes', {'Original': {}}),
#              ('diagnostics_Image-original_Hash',
#               '0ba1a3e612478ba76176b09d855ca1b97ee0cab3'),
#              ('diagnostics_Image-original_Dimensionality', '3D'),
#              ('diagnostics_Image-original_Spacing',
#               (0.9707030057907104, 0.9707030057907104, 1.0)),
#              ('diagnostics_Image-original_Size', (512, 512, 231)),
#              ('diagnostics_Image-original_Mean', -1018.1767935484519),
#              ('diagnostics_Image-original_Minimum', -3024.0),
#              ('diagnostics_Image-original_Maximum', 1410.0),
#              ('diagnostics_Mask-original_Hash',
#               '4df3e8a697ca69ee3a92b5725328234197289cc1'),
#              ('diagnostics_Mask-original_Spacing',
#               (0.9707030057907104, 0.9707030057907104, 1.0)),
#              ('diagnostics_Mask-original_Size', (512, 512, 231)),
#              ('diagnostics_Mask-original_BoundingBox',
#               (114, 225, 172, 32, 26, 23)),
#              ('diagnostics_Mask-original_VoxelNum', 6619),
#              ('diagnostics_Mask-original_VolumeNum', 1),
#              ('diagnostics_Mask-original_CenterOfMassIndex',
#               (127.50626982927935, 238.25351261519867, 182.7276023568515)),
#              ('diagnostics_Mask-original_CenterOfMass',
#               (-124.02928367131497, -17.226599164231686, -74.27239764314851)),
#              ('diagnostics_Image-interpolated_Spacing', (1.0, 1.0, 1.0)),
#              ('diagnostics_Image-interpolated_Size', (43, 38, 35)),
#              ('diagnostics_Image-interpolated_Mean', 18.96983738415807),
#              ('diagnostics_Image-interpolated_Minimum', -889.0),
#              ('diagnostics_Image-interpolated_Maximum', 105.0),
#              ('diagnostics_Mask-interpolated_Spacing', (1.0, 1.0, 1.0)),
#              ('diagnostics_Mask-interpolated_Size', (43, 38, 35)),
#              ('diagnostics_Mask-interpolated_BoundingBox',
#               (6, 6, 6, 31, 26, 23)),
#              ('diagnostics_Mask-interpolated_VoxelNum', 6376),
#              ('diagnostics_Mask-interpolated_VolumeNum', 1),
#              ('diagnostics_Mask-interpolated_CenterOfMassIndex',
#               (18.92314930991217, 19.22835633626098, 16.708594730238396)),
#              ('diagnostics_Mask-interpolated_CenterOfMass',
#               (-123.862205244741, -17.256995166634375, -74.29140526976161)),
#              ('diagnostics_Mask-interpolated_Mean', 5.5658720200752825),
#              ('diagnostics_Mask-interpolated_Minimum', -48.0),
#              ('diagnostics_Mask-interpolated_Maximum', 77.0),
#              ('original_shape_Maximum2DDiameterSlice', array(32.28002478)),
#              ('original_shape_Maximum2DDiameterColumn', array(31.57530681)),
#              ('original_shape_Maximum2DDiameterRow', array(27.20294102)),
#              ('original_shape_MajorAxisLength', 25.94717502585935),
#              ('original_shape_MinorAxisLength', 21.808404416897613),
#              ('original_shape_VoxelVolume', 6376.0),
#              ('original_firstorder_Mean', array(5.56587202)),
#              ('original_firstorder_Median', array(4.)),
#              ('original_firstorder_StandardDeviation', array(18.00324248))])
